# %%
from classifier.knn import KNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Mengakses fitur Gabor
df_gabor = pd.read_csv('dataset/ExtractResult/gabor/gabor_features.csv')
df_gabor
# Out:
#             mean        std  skewness  kurtosis        energi      fase  label
# 0     1072.41800  344.47015  0.910663  1.675312  2.078704e+10  0.000000      0
# 1      808.78620  384.25674  0.069924  1.390039  1.313650e+10  0.014573      0
# 2      549.54297  354.27866 -0.150746 -0.458540  7.004338e+09  0.017449      0
# 3     1141.13840  371.44910  0.599915  1.688863  2.359577e+10  0.000000      0
# 4     1203.01860  574.17786 -0.822286 -0.074542  2.911328e+10  0.019750      0
# ...          ...        ...       ...       ...           ...       ...    ...
# 1140  1384.74440  524.00226 -0.196588 -1.209712  3.591529e+10  0.000000      2
# 1141  1167.39950  558.95280 -0.390426 -0.913805  2.744729e+10  0.012272      2
# 1142   971.64810  399.82250  0.317966  0.444536  1.808725e+10  0.000000      2
# 1143   807.58344  521.63104  0.259587 -0.174910  1.514357e+10  0.017066      2
# 1144   539.56854  427.58456  0.236700 -0.775163  7.765406e+09  0.018024      2
#
# [1145 rows x 7 columns]

# %%
# Pemisahan Dataset

X_train, X_test, y_train, y_test = train_test_split(df_gabor.drop('label', axis=1), df_gabor['label'], test_size=0.2, random_state=42)

# %%
model = KNN(k=15)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred, average='micro')
f1 = f1_score(y_test, y_pred, average='micro')

print(acc)
print(prec)
print(rec)
print(f1)
# Out:
# 0.4497816593886463
# 0.4497816593886463
# 0.4497816593886463
# 0.4497816593886463
